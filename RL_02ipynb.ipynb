# %% [markdown]
# <a href="https://colab.research.google.com/github/AIML25/RL_LAB/blob/main/RL_02ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# Part A - Machine Initialization
machines = ['A', 'B', 'C']

# Number of plays
N_play = 10

# Exploration probability
epsilon = 0.2

# Initialize N, R and Q tables
N = {'A': 0, 'B': 0, 'C': 0}
R = {'A': 0, 'B': 0, 'C': 0}
Q = {'A': 0.0, 'B': 0.0, 'C': 0.0}

print("Initial Tables")
print("N =", N)
print("R =", R)
print("Q =", Q)

# Play the machines 10 times
for play in range(1, N_play + 1):

    # Generate random number
    r = random.random()

    # Epsilon-Greedy Decision
    if r < epsilon:
        # Exploration
        selected_machine = random.choice(machines)
        decision = "Exploration"
    else:
        # Exploitation
        max_q = max(Q.values())

        # Select machine with highest Q-value
        best_machines = [
            machine for machine in machines
            if Q[machine] == max_q
        ]

        selected_machine = random.choice(best_machines)
        decision = "Exploitation"

    print("\nPlay", play)
    print("Random number:", round(r, 4))
    print("Decision:", decision)
    print("Selected Machine:", selected_machine)

    # Part C - Reward Collection
    reward = float(input("Enter reward: "))

    # Part D - Update N
    N[selected_machine] += 1

    # Update total reward R
    R[selected_machine] += reward

    # Incremental sample-average formula
    Q[selected_machine] = (
        Q[selected_machine]
        + (reward - Q[selected_machine]) / N[selected_machine]
    )

    print("Updated N:", N)
    print("Updated R:", R)
    print("Updated Q:", Q)


# Part E - Display Final Results
print("\n========== FINAL RESULTS ==========")

print("\nMachine\tN\tR\tQ-value")

for machine in machines:
    print(
        machine,
        "\t", N[machine],
        "\t", R[machine],
        "\t", round(Q[machine], 2)
    )

print("\nFinal Participation Counts:")
print(N)

print("\nFinal Rewards:")
print(R)

print("\nFinal Q-values:")
print(Q)
# Out:
# Initial Tables
# N = {'A': 0, 'B': 0, 'C': 0}
# R = {'A': 0, 'B': 0, 'C': 0}
# Q = {'A': 0.0, 'B': 0.0, 'C': 0.0}
#
# Play 1
# Random number: 0.8284
# Decision: Exploitation
# Selected Machine: B
# Enter reward: 3
# Updated N: {'A': 0, 'B': 1, 'C': 0}
# Updated R: {'A': 0, 'B': 3.0, 'C': 0}
# Updated Q: {'A': 0.0, 'B': 3.0, 'C': 0.0}
#
# Play 2
# Random number: 0.8004
# Decision: Exploitation
# Selected Machine: B
# Enter reward: 4
# Updated N: {'A': 0, 'B': 2, 'C': 0}
# Updated R: {'A': 0, 'B': 7.0, 'C': 0}
# Updated Q: {'A': 0.0, 'B': 3.5, 'C': 0.0}
#
# Play 3
# Random number: 0.9364
# Decision: Exploitation
# Selected Machine: B
# Enter reward: 6
# Updated N: {'A': 0, 'B': 3, 'C': 0}
# Updated R: {'A': 0, 'B': 13.0, 'C': 0}
# Updated Q: {'A': 0.0, 'B': 4.333333333333333, 'C': 0.0}
#
# Play 4
# Random number: 0.7938
# Decision: Exploitation
# Selected Machine: B
# Enter reward: 2
# Updated N: {'A': 0, 'B': 4, 'C': 0}
# Updated R: {'A': 0, 'B': 15.0, 'C': 0}
# Updated Q: {'A': 0.0, 'B': 3.75, 'C': 0.0}
#
# Play 5
# Random number: 0.9763
# Decision: Exploitation
# Selected Machine: B
# Enter reward: 7
# Updated N: {'A': 0, 'B': 5, 'C': 0}
# Updated R: {'A': 0, 'B': 22.0, 'C': 0}
# Updated Q: {'A': 0.0, 'B': 4.4, 'C': 0.0}
#
# Play 6
# Random number: 0.9146
# Decision: Exploitation
# Selected Machine: B
# Enter reward: 5
# Updated N: {'A': 0, 'B': 6, 'C': 0}
# Updated R: {'A': 0, 'B': 27.0, 'C': 0}
# Updated Q: {'A': 0.0, 'B': 4.5, 'C': 0.0}
#
# Play 7
# Random number: 0.0625
# Decision: Exploration
# Selected Machine: A
# Enter reward: 4
# Updated N: {'A': 1, 'B': 6, 'C': 0}
# Updated R: {'A': 4.0, 'B': 27.0, 'C': 0}
# Updated Q: {'A': 4.0, 'B': 4.5, 'C': 0.0}
#
# Play 8
# Random number: 0.1718
# Decision: Exploration
# Selected Machine: B
# Enter reward: 8
# Updated N: {'A': 1, 'B': 7, 'C': 0}
# Updated R: {'A': 4.0, 'B': 35.0, 'C': 0}
# Updated Q: {'A': 4.0, 'B': 5.0, 'C': 0.0}
#
# Play 9
# Random number: 0.3597
# Decision: Exploitation
# Selected Machine: B
# Enter reward: 6
# Updated N: {'A': 1, 'B': 8, 'C': 0}
# Updated R: {'A': 4.0, 'B': 41.0, 'C': 0}
# Updated Q: {'A': 4.0, 'B': 5.125, 'C': 0.0}
#
# Play 10
# Random number: 0.1272
# Decision: Exploration
# Selected Machine: B
# Enter reward: 7
# Updated N: {'A': 1, 'B': 9, 'C': 0}
# Updated R: {'A': 4.0, 'B': 48.0, 'C': 0}
# Updated Q: {'A': 4.0, 'B': 5.333333333333333, 'C': 0.0}
#
# ========== FINAL RESULTS ==========
#
# Machine	N	R	Q-value
# A 	 1 	 4.0 	 4.0
# B 	 9 	 48.0 	 5.33
# C 	 0 	 0 	 0.0
#
# Final Participation Counts:
# {'A': 1, 'B': 9, 'C': 0}
#
# Final Rewards:
# {'A': 4.0, 'B': 48.0, 'C': 0}
#
# Final Q-values:
# {'A': 4.0, 'B': 5.333333333333333, 'C': 0.0}

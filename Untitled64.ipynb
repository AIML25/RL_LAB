# %% [markdown]
# <a href="https://colab.research.google.com/github/AIML25/RL_LAB/blob/main/Untitled64.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gymnasium

# %%
import gymnasium as gym
import random

# Create environment
env = gym.make("CliffWalking-v1")

num_episodes = 10

for episode in range(num_episodes):

    # Reset environment
    state, info = env.reset()

    total_reward = 0
    terminated = False
    truncated = False

    while not (terminated or truncated):

        # Identify available actions
        action = env.action_space.sample()

        # Execute action
        next_state, reward, terminated, truncated, info = env.step(action)

        # Add reward
        total_reward += reward

        # Move to next state
        state = next_state

    print(f"Episode {episode + 1}: Total Reward = {total_reward}")

env.close()
# Out:
# Episode 1: Total Reward = -73077
# Episode 2: Total Reward = -10841
# Episode 3: Total Reward = -21092
# Episode 4: Total Reward = -3460
# Episode 5: Total Reward = -153747
# Episode 6: Total Reward = -4828
# Episode 7: Total Reward = -139458
# Episode 8: Total Reward = -14422
# Episode 9: Total Reward = -56654
# Episode 10: Total Reward = -62863

# %%
import gymnasium as gym

env = gym.make("CliffWalking-v1")

num_episodes = 10
episode_rewards = []

for episode in range(num_episodes):

    state, info = env.reset()

    total_reward = 0
    terminated = False
    truncated = False

    while not (terminated or truncated):

        # Select a random action
        action = env.action_space.sample()

        # Perform action
        next_state, reward, terminated, truncated, info = env.step(action)

        # Update total reward
        total_reward += reward

        # Update state
        state = next_state

    episode_rewards.append(total_reward)

    print(f"Episode {episode + 1}: Total Reward = {total_reward}")

# Calculate average reward
average_reward = sum(episode_rewards) / len(episode_rewards)

print("\nAverage Reward =", average_reward)

env.close()
# Out:
# Episode 1: Total Reward = -20419
# Episode 2: Total Reward = -3465
# Episode 3: Total Reward = -29925
# Episode 4: Total Reward = -62932
# Episode 5: Total Reward = -19467
# Episode 6: Total Reward = -88590
# Episode 7: Total Reward = -194645
# Episode 8: Total Reward = -63904
# Episode 9: Total Reward = -143131
# Episode 10: Total Reward = -45479
#
# Average Reward = -67195.7

# %%
import gymnasium as gym

env = gym.make("Taxi-v4")

num_episodes = 10
episode_rewards = []

for episode in range(num_episodes):

    state, info = env.reset()

    total_reward = 0
    terminated = False
    truncated = False

    while not (terminated or truncated):

        # Select random action
        action = env.action_space.sample()

        # Execute action
        next_state, reward, terminated, truncated, info = env.step(action)

        # Add reward
        total_reward += reward

        # Update state
        state = next_state

    episode_rewards.append(total_reward)

    print(f"Episode {episode + 1}: Total Reward = {total_reward}")

# Calculate average reward
average_reward = sum(episode_rewards) / len(episode_rewards)

print("\nAverage Reward =", average_reward)

env.close()
# Out:
# Episode 1: Total Reward = -821
# Episode 2: Total Reward = -740
# Episode 3: Total Reward = -875
# Episode 4: Total Reward = -695
# Episode 5: Total Reward = -758
# Episode 6: Total Reward = -803
# Episode 7: Total Reward = -749
# Episode 8: Total Reward = -884
# Episode 9: Total Reward = -785
# Episode 10: Total Reward = -579
#
# Average Reward = -768.9
